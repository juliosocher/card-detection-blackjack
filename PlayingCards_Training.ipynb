# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.8/823.8 kB 15.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("cadyzedevelopmenthub").project("card-detection-zk7wu")
version = project.version(12)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.63, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Card-Detection-12 in yolov8:: 100%|██████████| 12884/12884 [00:01<00:00, 6779.17it/s]

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 417MB/s]

# %%
results = model.train(data='/content/data.yaml',epochs=50, imgsz=640, patience=50, optimizer='SGD', batch=16)
# Out:
# Ultralytics YOLOv8.2.63 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model('/content/AcetoFive.JPG')
# Out:
# image 1/1 /content/AcetoFive.JPG: 480x640 1 2D, 1 3S, 1 4H, 3 5Cs, 1 7S, 1 AS, 86.0ms
# Speed: 2.5ms preprocess, 86.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import os
import cv2

plot = results[0].plot()
plot = cv2.cvtColor(plot, cv2.COLOR_BGR2RGB)

# Convert to PIL Image for display
display_img = Image.fromarray(plot)

plt.imshow(display_img)
plt.axis('off')
# Out:
# (-0.5, 1919.5, 1439.5, -0.5)

# %%
model.save('/content/model_50_epochs.pt')
